# %%
from mk_filter import *
import soundfile as sf
from impulse import calc_RT
import csv

# %%
#  benchmarkチェック

sweep = sf.read(f'./sweep.wav')
sweep_inv = sf.read(f'./sweep_inv.wav')

# fc = 1000
# lowcut, highcut = calc_f_cutoff(fc)  
# sos, IRlen = mk_passFilt(lowcut, highcut)
# data_filtered = sosfiltfilt(sos, data[0], padlen=IRlen)
# rt, schlader = calc_RT(data_filtered, decaydB=20, start_dB = 10)

check1 = sweep[0]
plt.plot(check1)
plt.xlabel("Sample")
plt.ylabel("Amplitude")
plt.show()

check2 = sweep_inv[0]
plt.plot(check2)
plt.xlabel("Sample")
plt.ylabel("Amplitude")
plt.show()
